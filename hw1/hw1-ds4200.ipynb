# %%
import pandas as pd

# %%
class_df = pd.read_csv('hw-01-class-data - data.csv')

# %%
class_df
# Out:
#     In which country were you born? In which city were you born?  \
# 0                               NaN                          NaN
# 1                     United States      Los Angeles, California
# 2                       Netherlands                      Haarlem
# 3                     United States          Rockville, Maryland
# 4                     United States                      Warwick
# ..                              ...                          ...
# 102                        Ethiopia                  Addis Abeba
# 103                             USA                      Yonkers
# 104        United States of America                      Chicago
# 105                           India                    Hyderabad
# 106                   United States             Colorado Springs
#
#     In which languages (spoken, not programming!) are you proficient? (Please list languages separated by commas).   \
# 0                                                  NaN
# ...

# %%
class_df.dropna(inplace=True)
for x in class_df.columns:
    class_df[x] = class_df[x].str.lower()

# %%
class_df
# Out:
#     In which country were you born? In which city were you born?  \
# 2                       netherlands                      haarlem
# 4                     united states                      warwick
# 6          united states of america                       boston
# 7                             india                       mumbai
# 8                     united states                       edison
# ..                              ...                          ...
# 102                        ethiopia                  addis abeba
# 103                             usa                      yonkers
# 104        united states of america                      chicago
# 105                           india                    hyderabad
# 106                   united states             colorado springs
#
#     In which languages (spoken, not programming!) are you proficient? (Please list languages separated by commas).   \
# 2                                       dutch, english
# ...

# %%
class_df.to_csv('a1_class_data_clean.csv',header=True)
